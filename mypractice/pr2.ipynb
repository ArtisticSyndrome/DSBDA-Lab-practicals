# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import GaussianNB
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv('../student.csv')

# %%
print(df.isnull().sum())
print(df.info)
print(df.describe)
print(df.shape)
# Out:
# Name      0
# Gender    0
# PG        0
# Marks     1
# Age       0
# dtype: int64
# <bound method DataFrame.info of   Name Gender   PG  Marks  Age
# 0    A      M  Yes   50.0   20
# 1    B      F   No   60.0   21
# 2    C      M  Yes   40.0   22
# 3    D      F   No    NaN   23>
# <bound method NDFrame.describe of   Name Gender   PG  Marks  Age
# 0    A      M  Yes   50.0   20
# 1    B      F   No   60.0   21
# 2    C      M  Yes   40.0   22
# 3    D      F   No    NaN   23>
# (4, 5)

# %%
df['marks_norm'] = (df['Marks'] - df['Marks'].min()) / (df['Marks'].max() - df['Marks'].min())

# %%
df.boxplot(column = ['marks_norm'])
plt.show()

# %%
df['PG'] = df['PG'].map({'Yes' : 1, 'No' : 0})

# %%
df.head()
# Out:
#   Name Gender  PG  Marks  Age  marks_norm
# 0    A      M   1   50.0   20         0.5
# 1    B      F   0   60.0   21         1.0
# 2    C      M   1   40.0   22         0.0
# 3    D      F   0    NaN   23         NaN
