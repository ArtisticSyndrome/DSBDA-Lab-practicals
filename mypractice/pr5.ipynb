# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import GaussianNB
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv('../data.csv')

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of    ID AgeGroup  income  JOB_ID
# 0   1    Youth   30000     101
# 1   2    Adult   60000     102
# 2   3    Youth   35000     101
# 3   4   Senior   50000     103
# 4   5    Adult   65000     102>

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of    ID AgeGroup  income  JOB_ID
# 0   1    Youth   30000     101
# 1   2    Adult   60000     102
# 2   3    Youth   35000     101
# 3   4   Senior   50000     103
# 4   5    Adult   65000     102>

# %%
print(df['income'].agg(['mean','median','min']))
# Out:
# mean      48000.0
# median    50000.0
# min       30000.0
# Name: income, dtype: float64

# %%
print(df[['income']].agg(['mean','median','min']))
# Out:
#          income
# mean    48000.0
# median  50000.0
# min     30000.0

# %%
print(df.groupby('AgeGroup')['income'].describe())
# Out:
#           count     mean          std      min      25%      50%      75%  \
# AgeGroup
# Adult       2.0  62500.0  3535.533906  60000.0  61250.0  62500.0  63750.0
# Senior      1.0  50000.0          NaN  50000.0  50000.0  50000.0  50000.0
# Youth       2.0  32500.0  3535.533906  30000.0  31250.0  32500.0  33750.0
#
#               max
# AgeGroup
# Adult     65000.0
# Senior    50000.0
# Youth     35000.0
