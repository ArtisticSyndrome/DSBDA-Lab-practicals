# %%
from collections import Counter
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer


doc = 'Data science uses statistics and machine learning for insights.'

# %%
try:
    token = word_tokenize(doc.lower())
    post_tags = nltk.post_tags(token)
    stops = set(stopwords.words("English"))
    filtered = [t for t in token if t.isalpha() and t not in stops]
    stemmer = PorterStemmer()
    lemma = WordNetLemmatizer()
    stemmed = [stemmer.stem(t) for t in filtered]
    lemmatized = [lemma.lemmatize(t) for t in filtered]
    
except Exception as e:
    tokens = [t.strip('.,').lower() for t in doc.split()]
    pos_tags = []
    filtered = [t for t in tokens if t.isalpha()]
    stemmed = filtered
    lemmatized = filtered

# %%
print('Tokens:', tokens)
print('POS:', pos_tags)
print('Filtered:', filtered)
print('Stemmed:', stemmed)
print('Lemmatized:', lemmatized)

# Term Frequency (TF)
tf = Counter(filtered)
print('\nTF:', dict(tf))

# TF-IDF (for a single document this is still computable)
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform([doc])
terms = tfidf.get_feature_names_out()
scores = tfidf_matrix.toarray().ravel()
print('\nTF-IDF:', dict(zip(terms, scores)))
# Out:
# Tokens: ['data', 'science', 'uses', 'statistics', 'and', 'machine', 'learning', 'for', 'insights']
# POS: []
# Filtered: ['data', 'science', 'uses', 'statistics', 'and', 'machine', 'learning', 'for', 'insights']
# Stemmed: ['data', 'science', 'uses', 'statistics', 'and', 'machine', 'learning', 'for', 'insights']
# Lemmatized: ['data', 'science', 'uses', 'statistics', 'and', 'machine', 'learning', 'for', 'insights']
#
# TF: {'data': 1, 'science': 1, 'uses': 1, 'statistics': 1, 'and': 1, 'machine': 1, 'learning': 1, 'for': 1, 'insights': 1}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 12
#       8 tf = Counter(filtered)
#       9 print('\nTF:', dict(tf))
#      10
#      11 # TF-IDF (for a single document this is still computable)
# ---> 12 tfidf = TfidfVectorizer()
#      13 tfidf_matrix = tfidf.fit_transform([doc])
#      14 terms = tfidf.get_feature_names_out()
#      15 scores = tfidf_matrix.toarray().ravel()
#
# NameError: name 'TfidfVectorizer' is not defined
